# %% [markdown]
# Kelompok 7
# - Dwiyasa Nakula 5027221001
# - Muhammad Afif 5027221032
# - Iki Adfi Nur Mohamad 5027221033

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load dataset
data_train1 = pd.read_csv('training_dataset_1.csv')
data_train2 = pd.read_csv('training_dataset_2.csv')
data_test = pd.read_csv('test_dataset.csv')


# Combine training data
data_train = pd.concat([data_train1, data_train2], ignore_index=True)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# Convert DATETIME to datetime type
data_train['DATETIME'] = pd.to_datetime(data_train['DATETIME'], format='%d/%m/%y %H')
data_test['DATETIME'] = pd.to_datetime(data_test['DATETIME'], format='%d/%m/%y %H')

# Set DATETIME as index
data_train.set_index('DATETIME', inplace=True)
data_test.set_index('DATETIME', inplace=True)

# Separate features and target
X_train = data_train.drop(columns='ATT_FLAG')
y_train = data_train['ATT_FLAG']
X_test = data_test.drop(columns='ATT_FLAG')
y_test = data_test['ATT_FLAG']

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Split training data into training and validation sets
X_train_split, X_val, y_train_split, y_val = train_test_split(X_train_scaled, y_train, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Build ANN model
ann_model = Sequential([
    Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile model
ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model with validation data
history = ann_model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_data=(X_test_scaled, y_test))

# Evaluate model
ann_loss, ann_accuracy = ann_model.evaluate(X_test_scaled, y_test, verbose=0)
print(f'ANN Test Accuracy: {ann_accuracy}')

# Get validation accuracy from training history
val_accuracy = history.history['val_accuracy'][-1]
print(f'ANN Validation Accuracy: {val_accuracy}')
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9550 - loss: 0.1914 - val_accuracy: 0.8042 - val_loss: 2.0089
# Epoch 2/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9700 - loss: 0.1164 - val_accuracy: 0.8037 - val_loss: 1.2812
# Epoch 3/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9749 - loss: 0.0902 - val_accuracy: 0.8090 - val_loss: 1.2681
# Epoch 4/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9815 - loss: 0.0690 - val_accuracy: 0.8100 - val_loss: 1.1282
# Epoch 5/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.0673 - val_accuracy: 0.8195 - val_loss: 0.8722
# Epoch 6/50
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.models import Sequential

# Reshape data for CNN: (samples, timesteps, features)
X_train_cnn = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
X_test_cnn = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))

# Define the CNN model
cnn_model = Sequential([
    Conv1D(64, 2, activation='relu', input_shape=(X_train_scaled.shape[1], 1)),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile model
cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model with validation split
history = cnn_model.fit(X_train_cnn, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate model
cnn_loss, cnn_accuracy = cnn_model.evaluate(X_test_cnn, y_test, verbose=0)
print(f'CNN Test Accuracy: {cnn_accuracy}')

# Get validation accuracy from training history
val_accuracy = history.history['val_accuracy'][-1]
print(f'CNN Validation Accuracy: {val_accuracy}')
# Out:
# Epoch 1/50
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9835 - loss: 0.0353 - val_accuracy: 0.8099 - val_loss: 3.2589
# Epoch 2/50
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.1973e-06 - val_accuracy: 0.8099 - val_loss: 3.3750
# Epoch 3/50
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.1322e-06 - val_accuracy: 0.8099 - val_loss: 3.4932
# Epoch 4/50
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.4598e-06 - val_accuracy: 0.8099 - val_loss: 3.6059
# Epoch 5/50
# ...

# %%
from sklearn.model_selection import train_test_split
from keras.layers import SimpleRNN, Dense
from keras.models import Sequential

# Split training data into training and validation sets
X_train_split, X_val, y_train_split, y_val = train_test_split(X_train_scaled, y_train, test_size=0.2, random_state=42)

# Reshape data for RNN
X_train_rnn = X_train_split.reshape((X_train_split.shape[0], X_train_split.shape[1], 1))
X_val_rnn = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))
X_test_rnn = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))

# Define the RNN model
model = Sequential()
model.add(SimpleRNN(units=50, input_shape=(X_train_rnn.shape[1], X_train_rnn.shape[2])))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_rnn, y_train_split, epochs=20, batch_size=10, validation_data=(X_val_rnn, y_val), verbose=1)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_rnn, y_test, verbose=0)
print(f'RNN Test Accuracy: {test_accuracy}')

# Get validation accuracy from training history
val_accuracy = history.history['val_accuracy'][-1]
print(f'RNN Validation Accuracy: {val_accuracy}')
# Out:
# Epoch 1/20
# c:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1035/1035 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9336 - loss: 0.2111 - val_accuracy: 0.9726 - val_loss: 0.1201
# Epoch 2/20
# 1035/1035 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9573 - loss: 0.1631 - val_accuracy: 0.9656 - val_loss: 0.1435
# Epoch 3/20
# 1035/1035 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9621 - loss: 0.1581 - val_accuracy: 0.9691 - val_loss: 0.1401
# Epoch 4/20
# 1035/1035 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9637 - loss: 0.1540 - val_accuracy: 0.9687 - val_loss: 0.1371
# Epoch 5/20
# 1035/1035 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9648 - loss: 0.1501 - val_accuracy: 0.9687 - val_loss: 0.1369
# Epoch 6/20
# ...
